# %%
print("ein testing0")
print("does ein sync with browser, yes! on relaod of browser")
# %matplotlib inline
# Out:
# ein testing0
# does ein sync with browser, yes! on relaod of browser

# %% [markdown]
# Notes can be entered in markdown mode in this buffer

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
plt.subplot(2, 2, 2)
plt.plot(X, C)
plt.plot(X, S)

# %%
import pandas as pd
df1 = pd.DataFrame(X)
#use pytools-pandas-to-ses to send & view this in emacs spreadsheet ses buffer

# %% [markdown]
# ###################################################################################################
# This is the end of the scipy-lecture-notes/ tutorial
#
# Beginning of
# https://machinelearningmastery.com/visualize-machine-learning-data-python-pandas/
